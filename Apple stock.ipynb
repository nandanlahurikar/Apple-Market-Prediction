# %%
import numpy as np
import csv
from sklearn.svm import SVR
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df_aapl = pd.read_csv("aapl.csv")
df_aapl.head()
# Out:
#         Date    Open    High     Low   Close    Volume
# 0  30-Jun-17  144.45  144.96  143.78  144.02  23024107
# 1  29-Jun-17  144.71  145.13  142.28  143.68  31499368
# 2  28-Jun-17  144.49  146.11  143.16  145.83  22082432
# 3  27-Jun-17  145.01  146.16  143.62  143.73  24761891
# 4  26-Jun-17  147.17  148.28  145.38  145.82  25692361

# %%
pylab.rcParams['figure.figsize'] = (15, 9)
df_aapl["Close"].plot(grid = True)

# %%
df_aapl.count()
# Out:
# Date      239
# Open      239
# High      239
# Low       239
# Close     239
# Volume    239
# dtype: int64

# %%
df_appl.plot(figsize=(12,6))
plt.show()

# %%
x = df_aapl[['Pclass','Fare','SibSp','Parch','Sex','Embarked']]

y = df_aapl[['Survived']]

# sklearn linaer refgression

classifier = linear_model.LogisticRegression()
classifier_ = classifier.fit(x,y)

print(classifier_.score(x,y))
